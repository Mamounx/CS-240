# %%
from __future__ import print_function, division
import numpy as np
import nsfg

# %%
#Q1:
resp = nsfg.ReadFemResp()

# %%
resp.head(20)
# Out:
#     caseid  rscrinf  rdormres  rostscrn  rscreenhisp  rscreenrace  age_a  \
# 0     2298        1         5         5            1          5.0     27
# 1     5012        1         5         1            5          5.0     42
# 2    11586        1         5         1            5          5.0     43
# 3     6794        5         5         4            1          5.0     15
# 4      616        1         5         4            1          5.0     20
# 5      845        1         5         4            1          5.0     42
# 6    10333        5         5         3            1          5.0     17
# 7      855        5         5         4            5          5.0     22
# 8     8656        5         5         4            1          5.0     38
# 9     3566        5         5         4            5          5.0     21
# 10    5917        1         5         3            1          5.0     44
# 11    9200        5         5         3            1          5.0     26
# ...

# %%
resp.tail(30)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-94c8948b0384> in <module>()
# ----> 1 resp.tail(30)
#
# NameError: name 'resp' is not defined

# %%
rows = len(resp.index)
cloumns = len(resp.columns)
"There are %d rows and %d columns"%(rows, columns)
# Out:
# 'There are 7643 rows and 244 columns'

# %%
#Q2:
max = resp["agescrn"].max()
max
# Out:
# 44

# %%
min = resp["agescrn"].min()
min
# Out:
# 15

# %%
#Q3:
under25 = resp[resp["agescrn"] <= 25]

# %%
avgpreg = under25["numpregs"]
avgpreg.mean()
# Out:
# 0.70914326853851695

# %%
#Q4:
import thinkstats2
freq= thinkstats2.Hist(resp["fmarno"])
mari = resp.fmarno
mari
# Out:
# 0       0
# 1       2
# 2       1
# 3       0
# 4       0
# 5       1
# 6       0
# 7       0
# 8       1
# 9       0
# 10      1
# 11      1
# 12      1
# 13      2
# 14      1
# 15      0
# 16      1
# 17      1
# 18      0
# 19      1
# 20      0
# 21      1
# 22      1
# 23      1
# 24      1
# 25      0
# 26      0
# 27      1
# 28      1
# 29      1
#        ..
# 7613    0
# 7614    1
# 7615    0
# 7616    2
# 7617    1
# 7618    1
# 7619    1
# 7620    1
# 7621    0
# 7622    0
# 7623    0
# 7624    1
# 7625    0
# 7626    0
# 7627    0
# 7628    0
# 7629    1
# 7630    1
# 7631    0
# 7632    1
# 7633    1
# 7634    1
# 7635    1
# 7636    1
# 7637    1
# 7638    2
# 7639    0
# 7640    0
# 7641    0
# 7642    0
# Name: fmarno, Length: 7643, dtype: int64

# %%
import thinkplot
hist = thinkstats2.Hist(mari, label='Mariage frequancy')
thinkplot.Hist(hist, width = 0.5)
thinkplot.config(xlabel= "number of mariage", ylabel = "Frequancy")

# %%
#Q5:
neverMarried = resp[resp.fmarno == 0]
Married = resp[resp.fmarno >= 1]

# %%
neverMarried_hist = thinkstats2.Hist(notMarried.totincr, label = "Never Married")
Married_hist = thinkstats2.Hist(Married.totincr, label = "Married")

# %%
print(neverMarried_hist)
print(Married_hist)
# Out:
# Hist({1L: 205L, 2L: 193L, 3L: 163L, 4L: 239L, 5L: 238L, 6L: 268L, 7L: 300L, 8L: 288L, 9L: 276L, 10L: 215L, 11L: 257L, 12L: 252L, 13L: 236L, 14L: 387L})
# Hist({1L: 94L, 2L: 108L, 3L: 103L, 4L: 182L, 5L: 207L, 6L: 291L, 7L: 283L, 8L: 318L, 9L: 331L, 10L: 253L, 11L: 390L, 12L: 406L, 13L: 387L, 14L: 773L})

# %%
thinkplot.PrePlot(2)
thinkplot.Hist(neverMarried_hist, align= 'right', width= 0.5)
thinkplot.Hist(Married_hist, align= 'left', width= 0.5)
thinkplot.config(xlabel = 'Families', ylabel = 'Total income')

# %%
#Q6:
min_neverMarried = neverMarried.totincr.min()
max_neverMarried = neverMarried.totincr.max()
std_neverMarried = neverMarried.totincr.std()
var_neverMarried = neverMarried.totincr.var()
mean_neverMarried = neverMarried.totincr.mean()
print("Never Married: Minimum = %d, maximum = %d, Standard Deviation = %d, Variance = %d, Avrage = %d"%(min_neverMarried, max_neverMarried, 
                                                                                                        std_neverMarried, var_neverMarried, mean_neverMarried))
# Out:
# Never Married: Minimum = 1, maximum = 14, Standard Deviation = 3, Variance = 15, Avrage = 8

# %%
min_Married = Married.totincr.min()
max_Married = Married.totincr.max()
std_Married = Married.totincr.std()
var_Married = Married.totincr.var()
mean_Married = Married.totincr.mean()
print("Married: Minimum = %d, maximum = %d, Standard Deviation = %d, Variance = %d, Avrage = %d"%(min_Married, max_Married, 
                                                                                                        std_Married, var_Married, mean_Married))
# Out:
# Married: Minimum = 1, maximum = 14, Standard Deviation = 3, Variance = 13, Avrage = 9
